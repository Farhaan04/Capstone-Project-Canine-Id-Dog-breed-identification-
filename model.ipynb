# %%
import tensorflow as tf # Import TensorFlow for deep learning operations

# Check TensorFlow version
tf.__version__

# Define paths for training, testing, and validation data
train_path = "C:\\Users\\Farha\\OneDrive\\Desktop\\Cap-stone Project\\train"
test_path = "C:\\Users\\Farha\\OneDrive\\Desktop\\Cap-stone Project\\test"
valid_path = "C:\\Users\\Farha\\OneDrive\\Desktop\\Cap-stone Project\\valid"

import os # Import os for operating system related tasks (e.g., file operations, directory traversal)

files = []
label = []

# Walk through the training directory to gather file paths and labels
for dirname, _, filenames in os.walk(train_path):
    print(dirname) # Print the value of dirname
    for filename in filenames:
        files.append(os.path.join(dirname, filename))
        # Extract and store unique labels from directory names
        if len(dirname.split("\\")) >= 5 and dirname.split("\\")[4] not in label:
            label.append(dirname.split("\\")[4])


# Import required libraries for image data generation
from keras.preprocessing.image import ImageDataGenerator

# Create image data generator with rescaling and validation split
image_generator = ImageDataGenerator(rescale=1/255, validation_split=0.2)

# Generate training dataset from directory
train_dataset = image_generator.flow_from_directory(batch_size=32,
                                                 directory=train_path,
                                                 shuffle=True,
                                                 target_size=(224,224),
                                                 subset="training",
                                                 class_mode='categorical')

# Generate validation dataset from directory
validation_dataset = image_generator.flow_from_directory(batch_size=32,
                                                 directory=valid_path,
                                                 shuffle=True,
                                                 target_size=(224,224),
                                                 subset="validation",
                                                 class_mode='categorical')

# Define input shape for the model
IMG_SHAPE = (224,224,3)

# Load InceptionV3 model with pre-trained weights
base_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# Freeze base model layers to prevent them from being trained
base_model.trainable = False

# Build sequential model with InceptionV3 base, dropout, global average pooling, and dense output layer
model = tf.keras.Sequential([
  base_model,
  # tf.keras.layers.Conv2D(128, 3, activation='relu'),
  # Dropout layer to prevent overfitting
  tf.keras.layers.Dropout(0.2),
  # Global average pooling to reduce spatial dimensions
  tf.keras.layers.GlobalAveragePooling2D(),
  # Output layer with softmax activation for multi-class classification
  tf.keras.layers.Dense(70, activation='softmax')
])

# Set model name
model._name = "cool_code"

# Display model summary
model.summary()

# Compile model with Adam optimizer, categorical cross-entropy loss, and accuracy metric
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001), #Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train model using image data generators with specified epochs and validation data
hist = model.fit_generator(
    train_dataset,
    epochs=10,
    validation_data = validation_dataset
)

# Save trained model
model.save("dog_v2.h5")
# Out:
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Afghan
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\African Wild Dog
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Airedale
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\American Hairless
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\American Spaniel
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Basenji
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Basset
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Beagle
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bearded Collie
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bermaise
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bichon Frise
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Blenheim
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bloodhound
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bluetick
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Border Collie
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Borzoi
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Boston Terrier
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Boxer
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bull Mastiff
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bull Terrier
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Bulldog
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Cairn
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Chihuahua
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Chinese Crested
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Chow
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Clumber
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Cockapoo
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Cocker
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Collie
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Corgi
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Coyote
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Dalmation
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Dhole
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Dingo
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Doberman
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Elk Hound
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\French Bulldog
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\German Sheperd
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Golden Retriever
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Great Dane
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Great Perenees
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Greyhound
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Groenendael
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Irish Spaniel
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Irish Wolfhound
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Japanese Spaniel
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Komondor
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Labradoodle
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Labrador
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Lhasa
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Malinois
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Maltese
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Mex Hairless
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Newfoundland
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Pekinese
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Pit Bull
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Pomeranian
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Poodle
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Pug
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Rhodesian
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Rottweiler
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Saint Bernard
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Schnauzer
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Scotch Terrier
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Shar_Pei
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Shiba Inu
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Shih-Tzu
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Siberian Husky
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Vizsla
# C:\Users\Farha\OneDrive\Desktop\Cap-stone Project\train\Yorkie
# Found 6390 images belonging to 70 classes.
# Found 140 images belonging to 70 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 136s 2us/step
# Model: "cool_code"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  dropout (Dropout)           (None, 5, 5, 2048)        0
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 70)                143430
#
# =================================================================
# Total params: 21946214 (83.72 MB)
# Trainable params: 143430 (560.27 KB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# C:\Users\Farha\AppData\Local\Temp\ipykernel_18376\4000560997.py:83: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(
# Epoch 1/10
# 200/200 [==============================] - 180s 869ms/step - loss: 0.6782 - accuracy: 0.8327 - val_loss: 0.4384 - val_accuracy: 0.9286
# Epoch 2/10
# 200/200 [==============================] - 207s 1s/step - loss: 0.2226 - accuracy: 0.9272 - val_loss: 0.4465 - val_accuracy: 0.9286
# Epoch 3/10
# 200/200 [==============================] - 222s 1s/step - loss: 0.1594 - accuracy: 0.9455 - val_loss: 0.4776 - val_accuracy: 0.9071
# Epoch 4/10
# 200/200 [==============================] - 244s 1s/step - loss: 0.1168 - accuracy: 0.9606 - val_loss: 0.4981 - val_accuracy: 0.9286
# Epoch 5/10
# 200/200 [==============================] - 244s 1s/step - loss: 0.0950 - accuracy: 0.9685 - val_loss: 0.5159 - val_accuracy: 0.9214
# Epoch 6/10
# 200/200 [==============================] - 232s 1s/step - loss: 0.0712 - accuracy: 0.9762 - val_loss: 0.5188 - val_accuracy: 0.9143
# Epoch 7/10
# 200/200 [==============================] - 232s 1s/step - loss: 0.0532 - accuracy: 0.9851 - val_loss: 0.5418 - val_accuracy: 0.9214
# Epoch 8/10
# 200/200 [==============================] - 233s 1s/step - loss: 0.0489 - accuracy: 0.9850 - val_loss: 0.5006 - val_accuracy: 0.9357
# Epoch 9/10
# 200/200 [==============================] - 303s 2s/step - loss: 0.0374 - accuracy: 0.9892 - val_loss: 0.5038 - val_accuracy: 0.9214
# Epoch 10/10
# 200/200 [==============================] - 163s 817ms/step - loss: 0.0344 - accuracy: 0.9903 - val_loss: 0.5248 - val_accuracy: 0.9286
# C:\Users\Farha\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
